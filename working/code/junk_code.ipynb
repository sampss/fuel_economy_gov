# %%
# The long method

spacer = ['-'*20, '-'*2]
titleList = ['Data Discovery', 'Annual fuel consumption', 'Charging time', 'Mileage/Type', 'Carbon Emissions per mile', 'MPG/MPKwh']
descript_dict = {
    'barrels': 'Barrels - annual petroleum consumption 08 = fuelType1, A08 = fuelType2, 1 barrel = 42 gallons',
    'charge120': 'charge120 - time to charge an electric vehicle in hours at 120 V',
    'charge240': 'charge240 - time to charge an electric vehicle in hours at 240 V',
    'city08': f'city08 - city MPG for fuelType1',
    'city08U': f'city08U - unrounded city MPG for fuelType1',
    'cityA08': f'cityA08 - city MPG for fuelType2',
    'cityA08U': f'cityA08U - unrounded city MPG for fuelType2',
    'cityCD': f'cityCD - city gasoline consumption (gallons/100 miles) in charge depleting mode',
    'cityE': f'cityE - city electricity consumption in kw-hrs/100 miles',
    'cityUF': f'cityUF - EPA city utility factor (share of electricity) for PHEV',
    'co2': 'co2 - tailpipe CO2 in grams/mile for fuelType1',
    'co2A': 'co2A - tailpipe CO2 in grams/mile for fuelType2',
    'co2TailpipeGpm': 'co2TailpipeGpm - tailpipe CO2 in grams/mile for fuelType1',
    'co2TailpipeAGpm': 'co2TailpipeAGpm - tailpipe CO2 in grams/mile for fuelType2',
    'comb08': 'comb08 - combined MPG for fuelType1',
    'comb08U': 'comb08U - unrounded combined MPG for fuelType1',
    'combA08': 'combA08 - combined MPG for fuelType2',
    'combA08U': 'combA08U - unrounded combined MPG for fuelType2',
    'combE': 'combE - combined electricity consumption in kw-hrs/100 miles',
    'combinedCD': 'combCD - combined gasoline consumption (gallons/100 miles) in charge depleting mode',
    'combinedUF': 'combinedUF - EPA combined utility factor (share of electricity) for PHEV',
    'cylinders': 'cylinders - engine cylinders',
    'displ': 'displ - engine displacement in liters',
    'drive': 'drive - drive axle type',
    'engId': 'engId - EPA model type index',
    'eng_dscr': 'eng_dscr - engine descriptor; see http://www.fueleconomy.gov/feg/findacarhelp.shtml#engine',
    'feScore': 'feScore - EPA Fuel Economy Score (-1 = Not available)',
    'fuelCost08': 'fuelCost08 - annual fuel cost for fuelType1 ($) (7)',
    'fuelCostA08': 'fuelCostA08 - annual fuel cost for fuelType2 ($) (7)',
    'fuelType': 'fuelType - fuel type with fuelType1 and fuelType2 (if applicable)',
    'fuelType1': 'fuelType1 - fuel type 1. For single fuel vehicles, this will be the only fuel. For dual fuel vehicles, this will be the conventional fuel.',
    'fuelType2': 'fuelType2 - fuel type 2. For dual fuel vehicles, this will be the alternative fuel (e.g. E85, Electricity, CNG, LPG). For single fuel vehicles, this field is not used',
    'ghgScore': 'ghgScore - EPA GHG score (-1 = Not available)',
    'ghgScoreA': 'ghgScoreA - EPA GHG score for dual fuel vehicle running on the alternative fuel (-1 = Not available)',
    'guzzler': 'guzzler - if G or T, this vehicle is subject to the gas guzzler tax',
    'trans_dscr': 'trans_dscr - transmission descriptor',
    'highway08' : 'highway08 - highway MPG for fuelType1 (2), (11)',
    'highway08U': 'highway08U - unrounded highway MPG for fuelType1 (2), (3)',
    'highwayA08': 'highwayA08 - highway MPG for fuelType2 (2)',
    'highwayA08U': 'highwayA08U - unrounded highway MPG for fuelType2 (2),(3)',
    'highwayCD': 'highwayCD - highway gasoline consumption (gallons/100 miles) in charge depleting mode (4)',
    'highwayE': 'highwayE - highway electricity consumption in kw-hrs/100 miles',
    'highwayUF': 'highwayUF - EPA highway utility factor (share of electricity) for PHEV',
    'hlv': 'hlv - hatchback luggage volume (cubic feet) (8)',
    'hpv': 'hpv - hatchback passenger volume (cubic feet) (8)',
    'id': 'id - vehicle record id',
    'lv2': 'lv2 - 2 door luggage volume (cubic feet) (8)',
    'lv4': 'lv4 - 4 door luggage volume (cubic feet) (8)',
    'make': 'make - manufacturer (division)',
    'mfrCode': 'mfrCode - 3-character manufacturer code',
    'model': 'model - model name (carline)',
    'mpgData': 'mpgData - has My MPG data; see yourMpgVehicle and yourMpgDriverVehicle',
    'phevBlended': 'phevBlended - if true, this vehicle operates on a blend of gasoline and electricity in charge depleting mode',
    'pv2': 'pv2 - 2-door passenger volume (cubic feet) (8)',
    'pv4': 'pv4 - 4-door passenger volume (cubic feet) (8)',
    'range': 'range - No Descript - guess fuelType1',
    'rangeCity': 'rangeCity - No Descript - guess fuelType1',
    'rangeCityA': 'rangeCityA - EPA city range for fuelType2',
    'rangeHwy': 'rangeHwy - No Descript - guess fuelType1',
    'rangeHwyA': 'rangeHwyA - EPA highway range for fuelType2',
    'trany': 'trany - transmission',
    'UCity': 'UCity - unadjusted city MPG for fuelType1; see the description of the EPA test procedures',
    'UCityA': 'UCityA - unadjusted city MPG for fuelType2; see the description of the EPA test procedures',
    'UHighway': 'UHighway - unadjusted highway MPG for fuelType1; see the description of the EPA test procedures',
    'UHighwayA': 'UHighwayA - unadjusted highway MPG for fuelType2; see the description of the EPA test procedures',
    'VClass': 'VClass - EPA vehicle size class',
    'year': 'year - model year',
    'youSaveSpend': 'youSaveSpend - you save/spend over 5 years compared to an average car ($). Savings are positive; a greater amount spent yields a negative number. For dual fuel vehicles, this is the cost savings for gasoline',
    'sCharger': 'sCharger - if S, this vehicle is supercharged',
    'tCharger': 'tCharger - if T, this vehicle is turbocharged',
    'c240Dscr': 'c240Dscr - electric vehicle charger description',
    'charge240b': 'charge240b - time to charge an electric vehicle in hours at 240 V using the alternate charger',
    'c240bDscr': 'c240bDscr - electric vehicle alternate charger description',
    'createdOn': 'createdOn - date the vehicle record was created',
    'modifiedOn': 'modifiedOn - date the vehicle record was last modified',
    'startStop': 'startStop - vehicle has stop-start technology (Y, N, or blank for older vehicles)',
    'phevCity': 'phevCity - EPA composite gasoline-electricity city MPGe for plug-in hybrid vehicles',
    'phevHwy': 'phevHwy - EPA composite gasoline-electricity highway MPGe for plug-in hybrid vehicles',
    'phevComb': 'phevComb - EPA composite gasoline-electricity combined city-highway MPGe for plug-in hybrid vehicles',
    'baseModel': 'baseModel - base model name',
    'atvType': 'atvType -  type of alternative fuel or advanced technology vehicle',
    'rangeA': 'rangeA - EPA range for fuelType2',
    'evMotor': 'evMotor - electric motor (kw-hrs)'
}
contents_dict = {
    'barrels':f'barrels08 max: {fuel_econ['barrels08'].max()}, min: {fuel_econ['barrels08'].min()}',
    'barrelsA08':f'barrelsA08 max: {fuel_econ['barrelsA08'].max()}, min: {fuel_econ['barrelsA08'].min()}',
    'charge120':f'charge120: {fuel_econ['charge120'].unique()}',
    'charge240':f'charge240: {fuel_econ['charge240'].unique()}',
    'city08':f'city08: {fuel_econ['city08'].unique()}',
    'city08U':f'city08U: {fuel_econ['city08U'].unique()}',
    'cityA08':f'cityA08: {fuel_econ['cityA08'].unique()}',
    'cityA08U':f'cityA08U: {fuel_econ['cityA08U'].unique()}',
    'cityCD':f'cityCD: {fuel_econ['cityCD'].unique()}',
    'cityE':f'cityE: {fuel_econ['cityE'].unique()}',
    'cityUF':f'cityUF: {fuel_econ['cityUF'].unique()}',
    'co2':f'co2: {fuel_econ['co2'].unique()}',
    'co2A':f'co2A: {fuel_econ['co2A'].unique()}',
    'co2TailpipeGpm':f'co2TailpipeGpm: {fuel_econ['co2TailpipeGpm'].unique()}',
    'co2TailpipeAGpm':f'co2TailpipeAGpm: {fuel_econ['co2TailpipeAGpm'].unique()}',
    'comb08' : f'comb08: {fuel_econ['comb08'].unique()}',
    'comb08U' : f'comb08U: {fuel_econ['comb08U'].unique()}',
    'combA08' : f'combA08: {fuel_econ['combA08'].unique()}',
    'combA08U' : f'combA08U: {fuel_econ['combA08U'].unique()}',
    'combE' : f'combE: {fuel_econ['combE'].unique()}',
    'combinedCD' : f'combinedCD: {fuel_econ['combinedCD'].unique()}',
    'combinedUF': f'combinedUF: {fuel_econ["combinedUF"].unique()}',
    'cylinders': f'cylinders: {fuel_econ["cylinders"].unique()}',
    'displ': f'displ: {fuel_econ["displ"].unique()}',
    'drive': f'drive: {fuel_econ["drive"].unique()}',
    'engId': f'engId: {fuel_econ["engId"].unique()}',
    'eng_dscr': f'eng_dscr: {fuel_econ["eng_dscr"].unique()}',
    'feScore': f'feScore: {fuel_econ["feScore"].unique()}',
    'fuelCost08': f'fuelCost08: {fuel_econ["fuelCost08"].unique()}',
    'fuelCostA08': f'fuelCostA08: {fuel_econ["fuelCostA08"].unique()}',
    'fuelType': f'fuelType: {fuel_econ["fuelType"].unique()}',
    'fuelType1': f'fuelType1: {fuel_econ["fuelType1"].unique()}',
    'ghgScore': f'ghgScore: {fuel_econ["ghgScore"].unique()}',
    'ghgScoreA': f'ghgScoreA: {fuel_econ["ghgScoreA"].unique()}',
    'highway08': f'highway08: {fuel_econ["highway08"].unique()}',
    'highway08U': f'highway08U: {fuel_econ["highway08U"].unique()}',
    'highwayA08': f'highwayA08: {fuel_econ["highwayA08"].unique()}',
    'highwayA08U': f'highwayA08U: {fuel_econ["highwayA08U"].unique()}',
    'highwayCD': f'highwayCD: {fuel_econ["highwayCD"].unique()}',
    'highwayE': f'highwayE: {fuel_econ["highwayE"].unique()}',
    'highwayUF': f'highwayUF: {fuel_econ["highwayUF"].unique()}',
    'hlv': f'hlv: {fuel_econ["hlv"].unique()}',
    'hpv': f'hpv: {fuel_econ["hpv"].unique()}',
    'id': f'id: {fuel_econ["id"].unique()}',
    'lv2': f'lv2: {fuel_econ["lv2"].unique()}',
    'lv4': f'lv4: {fuel_econ["lv4"].unique()}',
    'make': f'make: {fuel_econ["make"].unique()}',
    'model': f'model: {fuel_econ["model"].unique()}',
    'mpgData': f'mpgData: {fuel_econ["mpgData"].unique()}',
    'phevBlended': f'phevBlended: {fuel_econ["phevBlended"].unique()}',
    'pv2': f'pv2: {fuel_econ["pv2"].unique()}',
    'pv4': f'pv4: {fuel_econ["pv4"].unique()}',
    'range': f'range: {fuel_econ["range"].unique()}',
    'rangeCity': f'rangeCity: {fuel_econ["rangeCity"].unique()}',
    'rangeCityA': f'rangeCityA: {fuel_econ["rangeCityA"].unique()}',
    'rangeHwy': f'rangeHwy: {fuel_econ["rangeHwy"].unique()}',
    'rangeHwyA': f'rangeHwyA: {fuel_econ["rangeHwyA"].unique()}',
    'trany': f'trany: {fuel_econ["trany"].unique()}',
    'UCity': f'UCity: {fuel_econ["UCity"].unique()}',
    'UCityA': f'UCityA: {fuel_econ["UCityA"].unique()}',
    'UHighway': f'UHighway: {fuel_econ["UHighway"].unique()}',
    'UHighwayA': f'UHighwayA: {fuel_econ["UHighwayA"].unique()}',
    'VClass': f'VClass: {fuel_econ["VClass"].unique()}',
    'year': f'year: {fuel_econ["year"].unique()}',
    'youSaveSpend': f'youSaveSpend: {fuel_econ["youSaveSpend"].unique()}',
    'baseModel': f'baseModel: {fuel_econ["baseModel"].unique()}',
    'guzzler': f'guzzler: {fuel_econ["guzzler"].unique()}',
    'trans_dscr': f'trans_dscr: {fuel_econ["trans_dscr"].unique()}',
    'tCharger': f'tCharger: {fuel_econ["tCharger"].unique()}',
    'sCharger': f'sCharger: {fuel_econ["sCharger"].unique()}',
    'atvType': f'atvType: {fuel_econ["atvType"].unique()}',
    'fuelType2': f'fuelType2: {fuel_econ["fuelType2"].unique()}',
    'rangeA': f'rangeA: {fuel_econ["rangeA"].unique()}',
    'evMotor': f'evMotor: {fuel_econ["evMotor"].unique()}',
    'mfrCode': f'mfrCode: {fuel_econ["mfrCode"].unique()}',
    'c240Dscr': f'c240Dscr: {fuel_econ["c240Dscr"].unique()}',
    'charge240b': f'charge240b: {fuel_econ["charge240b"].unique()}',
    'c240bDscr': f'c240bDscr: {fuel_econ["c240bDscr"].unique()}',
    'createdOn': f'createdOn: {fuel_econ["createdOn"].unique()}',
    'modifiedOn': f'modifiedOn: {fuel_econ["modifiedOn"].unique()}',
    'startStop': f'startStop: {fuel_econ["startStop"].unique()}',
    'phevCity': f'phevCity: {fuel_econ["phevCity"].unique()}',
    'phevHwy': f'phevHwy: {fuel_econ["phevHwy"].unique()}',
    'phevComb': f'phevComb: {fuel_econ["phevComb"].unique()}'
}

# Printing all keys in descript_dict to verify the existence of 'trans_dscr'
print(list(descript_dict.keys()))


print(titleList[0])
print(spacer[0])
print(titleList[1])
print(descript_dict['barrels'])
print(contents_dict['barrels'])
print(contents_dict['barrelsA08'])
print(spacer[0])
print(titleList[2])
print(descript_dict['charge120'])
print(contents_dict['charge120'])
print(descript_dict['charge240'])
print(contents_dict['charge240'])
print(spacer[0])
print(titleList[3])
print(descript_dict['city08'])
print(contents_dict['city08'])
print(spacer[1])
print(descript_dict['city08U'])
print(contents_dict['city08U'])
print(spacer[1])
print(descript_dict['cityA08'])
print(contents_dict['cityA08'])
print(spacer[1])
print(descript_dict['cityA08U'])
print(contents_dict['cityA08U'])
print(spacer[1])
print(descript_dict['cityCD'])
print(contents_dict['cityCD'])
print(spacer[1])
print(descript_dict['cityE'])
print(contents_dict['cityE'])
print(spacer[1])
print(descript_dict['cityUF'])
print(contents_dict['cityUF'])
print(spacer[0])
print(titleList[4])
print(descript_dict['co2'])
print(contents_dict['co2'])
print(spacer[1])
print(descript_dict['co2A'])
print(contents_dict['co2A'])
print(spacer[1])
print(descript_dict['co2TailpipeGpm'])
print(contents_dict['co2TailpipeGpm'])
print(spacer[1])
print(descript_dict['co2TailpipeAGpm'])
print(contents_dict['co2TailpipeAGpm'])
print(spacer[0])
print(titleList[5])
print(descript_dict['comb08'])
print(contents_dict['comb08'])
print(spacer[1])
print(descript_dict['comb08U'])
print(contents_dict['comb08U'])
print(spacer[1])
print(descript_dict['combA08'])
print(contents_dict['combA08'])
print(spacer[1])
print(descript_dict['combA08U'])
print(contents_dict['combA08U'])
print(spacer[1])
print(descript_dict['combE'])
print(contents_dict['combE'])
print(spacer[1])
print(descript_dict['combinedCD'])
print(contents_dict['combinedCD'])
print(descript_dict['combinedUF'])
print(contents_dict['combinedUF'])
print(spacer[1])
print(descript_dict['cylinders'])
print(contents_dict['cylinders'])
print(spacer[1])
print(descript_dict['displ'])
print(contents_dict['displ'])
print(spacer[1])
print(descript_dict['drive'])
print(contents_dict['drive'])
print(spacer[1])
print(descript_dict['engId'])
print(contents_dict['engId'])
print(spacer[1])
print(descript_dict['eng_dscr'])
print(contents_dict['eng_dscr'])
print(spacer[1])
print(descript_dict['feScore'])
print(contents_dict['feScore'])
print(spacer[1])
print(descript_dict['fuelCost08'])
print(contents_dict['fuelCost08'])
print(spacer[1])
print(descript_dict['fuelCostA08'])
print(contents_dict['fuelCostA08'])
print(spacer[1])
print(descript_dict['fuelType'])
print(contents_dict['fuelType'])
print(spacer[1])
print(descript_dict['fuelType1'])
print(contents_dict['fuelType1'])
print(spacer[1])
print(descript_dict['ghgScore'])
print(contents_dict['ghgScore'])
print(spacer[1])
print(descript_dict['ghgScoreA'])
print(contents_dict['ghgScoreA'])
print(spacer[1])
print(descript_dict['highway08'])
print(contents_dict['highway08'])
print(spacer[1])
print(descript_dict['highway08U'])
print(contents_dict['highway08U'])
print(spacer[1])
print(descript_dict['highwayA08'])
print(contents_dict['highwayA08'])
print(spacer[1])
print(descript_dict['highwayA08U'])
print(contents_dict['highwayA08U'])
print(spacer[1])
print(descript_dict['highwayCD'])
print(contents_dict['highwayCD'])
print(spacer[1])
print(descript_dict['highwayE'])
print(contents_dict['highwayE'])
print(spacer[1])
print(descript_dict['highwayUF'])
print(contents_dict['highwayUF'])
print(spacer[1])
print(descript_dict['hlv'])
print(contents_dict['hlv'])
print(spacer[1])
print(descript_dict['hpv'])
print(contents_dict['hpv'])
print(spacer[1])
print(descript_dict['id'])
print(contents_dict['id'])
print(spacer[1])
print(descript_dict['lv2'])
print(contents_dict['lv2'])
print(spacer[1])
print(descript_dict['lv4'])
print(contents_dict['lv4'])
print(spacer[1])
print(descript_dict['make'])
print(contents_dict['make'])
print(spacer[1])
print(descript_dict['mfrCode'])
print(contents_dict['mfrCode'])
print(spacer[1])
print(descript_dict['model'])
print(contents_dict['model'])
print(spacer[1])
print(descript_dict['mpgData'])
print(contents_dict['mpgData'])
print(spacer[1])
print(descript_dict['phevBlended'])
print(contents_dict['phevBlended'])
print(spacer[1])
print(descript_dict['pv2'])
print(contents_dict['pv2'])
print(spacer[1])
print(descript_dict['pv4'])
print(contents_dict['pv4'])
print(spacer[1])
print(descript_dict['range'])
print(contents_dict['range'])
print(spacer[1])
print(descript_dict['rangeCity'])
print(contents_dict['rangeCity'])
print(spacer[1])
print(descript_dict['rangeCityA'])
print(contents_dict['rangeCityA'])
print(spacer[1])
print(descript_dict['rangeHwy'])
print(contents_dict['rangeHwy'])
print(spacer[1])
print(descript_dict['rangeHwyA'])
print(contents_dict['rangeHwyA'])
print(spacer[1])
print(descript_dict['trany'])
print(contents_dict['trany'])
print(spacer[1])
print(descript_dict['UCity'])
print(contents_dict['UCity'])
print(spacer[1])
print(descript_dict['UCityA'])
print(contents_dict['UCityA'])
print(spacer[1])
print(descript_dict['UHighway'])
print(contents_dict['UHighway'])
print(spacer[1])
print(descript_dict['UHighwayA'])
print(contents_dict['UHighwayA'])
print(spacer[1])
print(descript_dict['VClass'])
print(contents_dict['VClass'])
print(spacer[1])
print(descript_dict['year'])
print(contents_dict['year'])
print(spacer[1])
print(descript_dict['youSaveSpend'])
print(contents_dict['youSaveSpend'])
print(spacer[1])
print(descript_dict['baseModel'])
print(contents_dict['baseModel'])
print(spacer[1])
print(descript_dict['guzzler'])
print(contents_dict['guzzler'])
print(spacer[1])
print(descript_dict['trans_dscr'])
print(contents_dict['trans_dscr'])
print(spacer[1])
print(descript_dict['tCharger'])
print(contents_dict['tCharger'])
print(spacer[1])
print(descript_dict['sCharger'])
print(contents_dict['sCharger'])
print(spacer[1])
print(descript_dict['atvType'])
print(contents_dict['atvType'])
print(spacer[1])
print(descript_dict['fuelType2'])
print(contents_dict['fuelType2'])
print(spacer[1])
print(descript_dict['rangeA'])
print(contents_dict['rangeA'])
print(spacer[1])
print(descript_dict['evMotor'])
print(contents_dict['evMotor'])
print(spacer[1])
print(descript_dict['mfrCode'])
print(contents_dict['mfrCode'])
print(spacer[1])
print(descript_dict['c240Dscr'])
print(contents_dict['c240Dscr'])
print(spacer[1])
print(descript_dict['charge240b'])
print(contents_dict['charge240b'])
print(spacer[1])
print(descript_dict['c240bDscr'])
print(contents_dict['c240bDscr'])
print(spacer[1])
print(descript_dict['createdOn'])
print(contents_dict['createdOn'])
print(spacer[1])
print(descript_dict['modifiedOn'])
print(contents_dict['modifiedOn'])
print(spacer[1])
print(descript_dict['startStop'])
print(contents_dict['startStop'])
print(spacer[1])
print(descript_dict['phevCity'])
print(contents_dict['phevCity'])
print(spacer[1])
print(descript_dict['phevHwy'])
print(contents_dict['phevHwy'])
print(spacer[1])
print(descript_dict['phevComb'])
print(contents_dict['phevComb'])

# Save this info to a txt file for examination
with open('../Documents/Column_Descript_Unique_Values.txt', 'w') as file:
    file.write(f"{titleList[0]}\n")
    file.write(f"{spacer[0]}\n")
    file.write(f"{titleList[1]}\n")
    file.write(f"{descript_dict['barrels']}\n")
    file.write(f"{contents_dict['barrels']}\n")
    file.write(f"{contents_dict['barrelsA08']}\n")
    file.write(f"{spacer[0]}\n")
    file.write(f"{titleList[2]}\n")
    file.write(f"{descript_dict['charge120']}\n")
    file.write(f"{contents_dict['charge120']}\n")
    file.write(f"{descript_dict['charge240']}\n")
    file.write(f"{contents_dict['charge240']}\n")
    file.write(f"{spacer[0]}\n")
    file.write(f"{titleList[3]}\n")
    file.write(f"{descript_dict['city08']}\n")
    file.write(f"{contents_dict['city08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['city08U']}\n")
    file.write(f"{contents_dict['city08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cityA08']}\n")
    file.write(f"{contents_dict['cityA08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cityA08U']}\n")
    file.write(f"{contents_dict['cityA08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cityCD']}\n")
    file.write(f"{contents_dict['cityCD']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cityE']}\n")
    file.write(f"{contents_dict['cityE']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cityUF']}\n")
    file.write(f"{contents_dict['cityUF']}\n")
    file.write(f"{spacer[0]}\n")
    file.write(f"{titleList[4]}\n")
    file.write(f"{descript_dict['co2']}\n")
    file.write(f"{contents_dict['co2']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['co2A']}\n")
    file.write(f"{contents_dict['co2A']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['co2TailpipeGpm']}\n")
    file.write(f"{contents_dict['co2TailpipeGpm']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['co2TailpipeAGpm']}\n")
    file.write(f"{contents_dict['co2TailpipeAGpm']}\n")
    file.write(f"{spacer[0]}\n")
    file.write(f"{titleList[5]}\n")
    file.write(f"{descript_dict['comb08']}\n")
    file.write(f"{contents_dict['comb08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['comb08U']}\n")
    file.write(f"{contents_dict['comb08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['combA08']}\n")
    file.write(f"{contents_dict['combA08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['combA08U']}\n")
    file.write(f"{contents_dict['combA08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['combE']}\n")
    file.write(f"{contents_dict['combE']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['combinedCD']}\n")
    file.write(f"{contents_dict['combinedCD']}\n")
    file.write(f"{descript_dict['combinedUF']}\n")
    file.write(f"{contents_dict['combinedUF']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['cylinders']}\n")
    file.write(f"{contents_dict['cylinders']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['displ']}\n")
    file.write(f"{contents_dict['displ']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['drive']}\n")
    file.write(f"{contents_dict['drive']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['engId']}\n")
    file.write(f"{contents_dict['engId']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['eng_dscr']}\n")
    file.write(f"{contents_dict['eng_dscr']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['feScore']}\n")
    file.write(f"{contents_dict['feScore']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['fuelCost08']}\n")
    file.write(f"{contents_dict['fuelCost08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['fuelCostA08']}\n")
    file.write(f"{contents_dict['fuelCostA08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['fuelType']}\n")
    file.write(f"{contents_dict['fuelType']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['fuelType1']}\n")
    file.write(f"{contents_dict['fuelType1']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['ghgScore']}\n")
    file.write(f"{contents_dict['ghgScore']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['ghgScoreA']}\n")
    file.write(f"{contents_dict['ghgScoreA']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highway08']}\n")
    file.write(f"{contents_dict['highway08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highway08U']}\n")
    file.write(f"{contents_dict['highway08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highwayA08']}\n")
    file.write(f"{contents_dict['highwayA08']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highwayA08U']}\n")
    file.write(f"{contents_dict['highwayA08U']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highwayCD']}\n")
    file.write(f"{contents_dict['highwayCD']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highwayE']}\n")
    file.write(f"{contents_dict['highwayE']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['highwayUF']}\n")
    file.write(f"{contents_dict['highwayUF']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['hlv']}\n")
    file.write(f"{contents_dict['hlv']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['hpv']}\n")
    file.write(f"{contents_dict['hpv']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['id']}\n")
    file.write(f"{contents_dict['id']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['lv2']}\n")
    file.write(f"{contents_dict['lv2']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['lv4']}\n")
    file.write(f"{contents_dict['lv4']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['make']}\n")
    file.write(f"{contents_dict['make']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['mfrCode']}\n")
    file.write(f"{contents_dict['mfrCode']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['model']}\n")
    file.write(f"{contents_dict['model']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['mpgData']}\n")
    file.write(f"{contents_dict['mpgData']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['phevBlended']}\n")
    file.write(f"{contents_dict['phevBlended']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['pv2']}\n")
    file.write(f"{contents_dict['pv2']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['pv4']}\n")
    file.write(f"{contents_dict['pv4']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['range']}\n")
    file.write(f"{contents_dict['range']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['rangeCity']}\n")
    file.write(f"{contents_dict['rangeCity']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['rangeCityA']}\n")
    file.write(f"{contents_dict['rangeCityA']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['rangeHwy']}\n")
    file.write(f"{contents_dict['rangeHwy']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['rangeHwyA']}\n")
    file.write(f"{contents_dict['rangeHwyA']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['trany']}\n")
    file.write(f"{contents_dict['trany']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['UCity']}\n")
    file.write(f"{contents_dict['UCity']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['UCityA']}\n")
    file.write(f"{contents_dict['UCityA']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['UHighway']}\n")
    file.write(f"{contents_dict['UHighway']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['UHighwayA']}\n")
    file.write(f"{contents_dict['UHighwayA']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['VClass']}\n")
    file.write(f"{contents_dict['VClass']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['year']}\n")
    file.write(f"{contents_dict['year']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['youSaveSpend']}\n")
    file.write(f"{contents_dict['youSaveSpend']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['baseModel']}\n")
    file.write(f"{contents_dict['baseModel']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['guzzler']}\n")
    file.write(f"{contents_dict['guzzler']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['trans_dscr']}\n")
    file.write(f"{contents_dict['trans_dscr']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['tCharger']}\n")
    file.write(f"{contents_dict['tCharger']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['sCharger']}\n")
    file.write(f"{contents_dict['sCharger']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['atvType']}\n")
    file.write(f"{contents_dict['atvType']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['fuelType2']}\n")
    file.write(f"{contents_dict['fuelType2']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['rangeA']}\n")
    file.write(f"{contents_dict['rangeA']}\n")
    file.write(f"{descript_dict['evMotor']}\n")
    file.write(f"{contents_dict['evMotor']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['mfrCode']}\n")
    file.write(f"{contents_dict['mfrCode']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['c240Dscr']}\n")
    file.write(f"{contents_dict['c240Dscr']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['charge240b']}\n")
    file.write(f"{contents_dict['charge240b']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['c240bDscr']}\n")
    file.write(f"{contents_dict['c240bDscr']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['createdOn']}\n")
    file.write(f"{contents_dict['createdOn']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['modifiedOn']}\n")
    file.write(f"{contents_dict['modifiedOn']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['startStop']}\n")
    file.write(f"{contents_dict['startStop']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['phevCity']}\n")
    file.write(f"{contents_dict['phevCity']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['phevHwy']}\n")
    file.write(f"{contents_dict['phevHwy']}\n")
    file.write(f"{spacer[1]}\n")
    file.write(f"{descript_dict['phevComb']}\n")
    file.write(f"{contents_dict['phevComb']}\n")
# Out:
# ['barrels', 'charge120', 'charge240', 'city08', 'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2', 'co2A', 'co2TailpipeGpm', 'co2TailpipeAGpm', 'comb08', 'comb08U', 'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders', 'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08', 'fuelCostA08', 'fuelType', 'fuelType1', 'fuelType2', 'ghgScore', 'ghgScoreA', 'guzzler', 'trans_dscr', 'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD', 'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make', 'mfrCode', 'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity', 'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA', 'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'sCharger', 'tCharger', 'c240Dscr', 'charge240b', 'c240bDscr', 'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy', 'phevComb', 'baseModel', 'atvType', 'rangeA', 'evMotor']
# Data Discovery
# --------------------
# ...

# %%
# old filtered data via pandas that was loaded into a dataframe.
# Deprecated as I am going to only load what I need from sqlite file

# vehicle_data_cleaned = vehicle_data[~vehicle_data['fuelType'].isin(remove_fuel_types)] #remove unwanted fuel types

# vehicle_data_cleaned = vehicle_data_cleaned[keep_columns] # remove unwanted columns

# vehicle_data_cleaned.shape # check data shape

# %%
# Deprecated and imported from a dot PY file

'''
descript_dict = {
    'barrels': 'annual petroleum consumption for fuelType1 and fuelType2 (1 barrel = 42 gallons)',
    'barrels08': 'annual petroleum consumption for fuelType1',
    'barrelsA08': 'annual petroleum consumption for fuelType2',
    'charge120': 'time to charge at 120V (hours)',
    'charge240': 'time to charge at 240V (hours)',
    'city08': 'city MPG for fuelType1',
    'city08U': 'unrounded city MPG for fuelType1',
    'cityA08': 'city MPG for fuelType2',
    'cityA08U': 'unrounded city MPG for fuelType2',
    'cityCD': 'city gasoline consumption in charge depleting mode (gallons/100 miles)',
    'cityE': 'city electricity consumption (kw-hrs/100 miles)',
    'cityUF': 'EPA city utility factor for PHEV',
    'co2': 'tailpipe CO2 for fuelType1 (grams/mile)',
    'co2A': 'tailpipe CO2 for fuelType2 (grams/mile)',
    'co2TailpipeGpm': 'tailpipe CO2 for fuelType1 (grams/mile)',
    'co2TailpipeAGpm': 'tailpipe CO2 for fuelType2 (grams/mile)',
    'comb08': 'combined MPG for fuelType1',
    'comb08U': 'unrounded combined MPG for fuelType1',
    'combA08': 'combined MPG for fuelType2',
    'combA08U': 'unrounded combined MPG for fuelType2',
    'combE': 'combined electricity consumption (kw-hrs/100 miles)',
    'combinedCD': 'combined gasoline consumption in charge depleting mode (gallons/100 miles)',
    'combinedUF': 'EPA combined utility factor for PHEV',
    'cylinders': 'engine cylinders',
    'displ': 'engine displacement (liters)',
    'drive': 'drive axle type',
    'engId': 'EPA model type index',
    'eng_dscr': 'engine descriptor',
    'feScore': 'EPA Fuel Economy Score (-1 = Not available)',
    'fuelCost08': 'annual fuel cost for fuelType1 ($)',
    'fuelCostA08': 'annual fuel cost for fuelType2 ($)',
    'fuelType': 'fuel type (fuelType1 and fuelType2, if applicable)',
    'fuelType1': 'primary fuel type for single or conventional fuel vehicles',
    'fuelType2': 'alternative fuel type for dual fuel vehicles',
    'ghgScore': 'EPA GHG score for fuelType1 (-1 = Not available)',
    'ghgScoreA': 'EPA GHG score for fuelType2 (-1 = Not available)',
    'guzzler': 'subject to gas guzzler tax (G or T)',
    'trans_dscr': 'transmission descriptor',
    'highway08': 'highway MPG for fuelType1',
    'highway08U': 'unrounded highway MPG for fuelType1',
    'highwayA08': 'highway MPG for fuelType2',
    'highwayA08U': 'unrounded highway MPG for fuelType2',
    'highwayCD': 'highway gasoline consumption in charge depleting mode (gallons/100 miles)',
    'highwayE': 'highway electricity consumption (kw-hrs/100 miles)',
    'highwayUF': 'EPA highway utility factor for PHEV',
    'hlv': 'hatchback luggage volume (cubic feet)',
    'hpv': 'hatchback passenger volume (cubic feet)',
    'id': 'vehicle record ID',
    'lv2': '2-door luggage volume (cubic feet)',
    'lv4': '4-door luggage volume (cubic feet)',
    'make': 'manufacturer (division)',
    'mfrCode': '3-character manufacturer code',
    'model': 'model name (carline)',
    'mpgData': 'has My MPG data',
    'phevBlended': 'PHEV operates on a blend of gasoline and electricity in charge depleting mode',
    'pv2': '2-door passenger volume (cubic feet)',
    'pv4': '4-door passenger volume (cubic feet)',
    'range': 'estimated range for fuelType1',
    'rangeCity': 'estimated city range for fuelType1',
    'rangeCityA': 'EPA city range for fuelType2',
    'rangeHwy': 'estimated highway range for fuelType1',
    'rangeHwyA': 'EPA highway range for fuelType2',
    'trany': 'transmission',
    'UCity': 'unadjusted city MPG for fuelType1',
    'UCityA': 'unadjusted city MPG for fuelType2',
    'UHighway': 'unadjusted highway MPG for fuelType1',
    'UHighwayA': 'unadjusted highway MPG for fuelType2',
    'VClass': 'EPA vehicle size class',
    'year': 'model year',
    'youSaveSpend': 'savings/spending over 5 years compared to an average car',
    'sCharger': 'supercharged (S)',
    'tCharger': 'turbocharged (T)',
    'c240Dscr': 'electric vehicle charger description',
    'charge240b': 'time to charge an electric vehicle at 240V (hours)',
    'c240bDscr': 'electric vehicle alternate charger description',
    'createdOn': 'vehicle record creation date',
    'modifiedOn': 'last modified date of the vehicle record',
    'startStop': 'vehicle has stop-start technology',
    'phevCity': 'EPA composite gasoline-electricity city MPGe for plug-in hybrid vehicles',
    'phevHwy': 'EPA composite gasoline-electricity highway MPGe for plug-in hybrid vehicles',
    'phevComb': 'EPA composite gasoline-electricity combined city-highway MPGe for plug-in hybrid vehicles',
    'baseModel': 'base model name',
    'atvType': 'type of alternative fuel or advanced technology vehicle',
    'rangeA': 'EPA range for fuelType2',
    'evMotor': 'electric motor (kw-hrs)'
}'''


# get names and unique values for each column in the column list
'''
with open('../Documents/Column_Descript_Unique_Values.txt', 'w') as file:
    for col in vehicle_data_cleaned:
        unique_values = vehicle_data_cleaned[col].unique()
        description = descript_dict.get(col, "No description available")
        file.write(f'{col}:  {description}\n')
        file.write(f"{spacer[1]}\n")
        for value in unique_values:
            file.write(f"{value}, ")
        file.write("\n" + "-"*10 + "\n")
'''
