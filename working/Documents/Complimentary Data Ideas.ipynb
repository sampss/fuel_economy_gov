# %% [markdown]
# ### Complementary Data
#
# 1. **Manufacturer-Specific Data:**
#    - Warranty information
#    - Safety ratings
#    - Recall history
#
# 2. **Economic and Environmental Data:**
#    - Fuel prices over time
#    - Carbon credit prices
#    - Environmental regulation changes
#
# 3. **Geographical Data:**
#    - Average commute distance in different regions
#    - Urban vs. rural vehicle usage patterns
#    - Regional weather conditions and their impact on vehicle performance
#
# 4. **User Data:**
#    - Owner demographics
#    - Usage patterns (e.g., average miles driven per year)
#    - Vehicle maintenance and repair costs
#
# 5. **Market Data:**
#    - Competitor vehicle specifications and performance
#    - Sales figures and market share for different vehicle models
#
# ### Potential Conclusions
#
# 1. **Efficiency Analysis:**
#    - Compare fuel efficiency across different vehicle makes and models.
#    - Identify trends in efficiency improvements over time.
#
# 2. **Environmental Impact:**
#    - Analyze the carbon footprint of different vehicle types and makes.
#    - Evaluate the impact of electric vehicles vs. conventional fuel vehicles on emissions.
#
# 3. **Economic Impact:**
#    - Assess the cost savings of electric vehicles based on fuel and maintenance costs.
#    - Determine the payback period for hybrid and electric vehicles.
#
# 4. **Consumer Preferences:**
#    - Identify popular vehicle models based on sales data and user demographics.
#    - Analyze how fuel efficiency and emissions influence consumer choices.
#
# 5. **Regulatory Impact:**
#    - Examine how changes in environmental regulations have affected vehicle emissions and efficiency.
#    - Forecast the impact of future regulations on the automotive market

# %% [markdown]
# ### Complementary Data 2
#
# 1. **Cost Analysis:**
#    - Purchase price
#    - Maintenance costs
#    - Insurance costs
#    - Resale value
#
# 2. **Environmental Impact:**
#    - Lifecycle CO2 emissions (including manufacturing and disposal)
#    - Emissions during operation
#    - Energy source for electricity (renewable vs. non-renewable)
#
# 3. **Performance Metrics:**
#    - Acceleration and top speed
#    - Range per charge/tank
#    - Charging/refueling time
#    - Battery life and replacement costs for electric and hybrid vehicles
#
# 4. **User Experience:**
#    - Owner satisfaction ratings
#    - Reliability ratings
#    - Availability of charging/refueling infrastructure
#    - Noise levels during operation
#
# 5. **Economic Factors:**
#    - Fuel/electricity costs over time
#    - Government incentives and rebates
#    - Tax benefits or penalties
#    - Depreciation rates
#
# ### Potential Conclusions
#
# 1. **Cost Efficiency:**
#    - Compare the total cost of ownership over the vehicle's lifetime.
#    - Determine which vehicle type offers the best value for money.
#
# 2. **Environmental Benefits:**
#    - Assess which vehicle type has the lowest overall environmental impact.
#    - Evaluate the benefits of using renewable energy sources for electric vehicles.
#
# 3. **Performance and Convenience:**
#    - Compare the performance metrics to see which vehicle type meets your needs.
#    - Analyze the availability and convenience of charging/refueling infrastructure.
#
# 4. **Consumer Preferences:**
#    - Identify trends in consumer satisfaction and reliability.
#    - Determine how government incentives influence consumer choices.

# %% [markdown]
# ### Cost Analysis Data
# 1. **Car Cost Insight**: This platform provides detailed maintenance records for various car brands, models, and years. It includes comprehensive cost tracking and predictive maintenance.
# 2. **Fleet Management Cost Analysis**: Fleetio offers tools for tracking expenses and calculating the total cost of ownership (TCO) for fleet management.
# 3. **Vehicle Life Cycle Cost Analysis Spreadsheet**: ExcelDemy provides methods for creating a vehicle life cycle cost analysis spreadsheet in Excel, covering acquisition costs, operating costs, maintenance costs, and more.
#
# ### Environmental Impact Data
# 1. **Greenhouse Gas Emissions from a Typical Passenger Vehicle**: The US EPA provides detailed information on greenhouse gas emissions from typical passenger vehicles, including CO2 emissions per mile and per gallon of fuel.
# 2. **Green Vehicle Guide**: The US EPA's Green Vehicle Guide offers information on light-duty vehicles, including emerging vehicle technology and alternative fuels.
# 3. **Automotive Trends Data**: The US EPA's Automotive Trends Report provides data on fuel economy, CO2 emissions, and vehicle attributes for various model years.
#
# ### Performance Metrics Data
# 1. **Guiding Metrics**: This article outlines the most critical metrics for the automotive industry, including units manufactured, total cost to manufacture, utilization rate, and manufacturing cycle time.
# 2. **AutoPi.io**: This guide explains various types of vehicle data, such as engine and performance data, fuel efficiency data, safety and diagnostic data, and more.
# 3. **Automotive Quest**: This article discusses key metrics for evaluating vehicle performance, including acceleration, fuel efficiency, and braking capabilities.
#
#
# ### Cost Analysis Data
# 1. **Car Cost Insight**: [Car Cost Insight](https://www.carcostinsight.com/)
# 2. **Fleet Management Cost Analysis**: [Fleetio](https://www.fleetio.com/blog/fleet-management-cost-analysis)
# 3. **Vehicle Life Cycle Cost Analysis Spreadsheet**: [ExcelDemy](https://www.exceldemy.com/vehicle-life-cycle-cost-analysis-excel-spreadsheet/)
#
# ### Environmental Impact Data
# 1. **Greenhouse Gas Emissions from a Typical Passenger Vehicle**: [US EPA](https://www.epa.gov/greenvehicles/greenhouse-gas-emissions-typical-passenger-vehicle)
# 2. **Green Vehicle Guide**: [US EPA](https://www.epa.gov/greenvehicles)
# 3. **Automotive Trends Data**: [US EPA](https://www.epa.gov/automotive-trends/explore-automotive-trends-data)
#
# ### Performance Metrics Data
# 1. **Guiding Metrics**: [Guiding Metrics](https://guidingmetrics.com/content/key-automotive-industry-metrics/)
# 2. **AutoPi.io**: [AutoPi.io](https://www.autopi.io/blog/the-meaning-of-vehicle-data/)
# 3. **Automotive Quest**: [Automotive Quest](https://automotivequest.com/vehicle-performance-metrics/)

# %% [markdown]
# # Gasoline and Electric Vehicle Fuel Assessment - Data Description (edited)
#
# | Field                   | Description                                                                 |
# |-------------------------|-----------------------------------------------------------------------------|
# | **est_petro_cons**      | annual petroleum consumption in barrels for fuelType1                       |
# | **charge_hours_240**    | time to charge an electric vehicle in hours at 240 V                        |
# | **co2**                 | tailpipe CO2 in grams/mile for fuelType1                                     |
# | **comb_MPG_MPGe**       | combined MPG for fuelType1                                                  |
# | **comb_kWh_100miles**   | combined electricity consumption in kw-hrs/100 miles                        |
# | **cylinders**           | engine cylinders                                                            |
# | **displ**               | engine displacement in liters                                               |
# | **drive**               | drive axle type                                                             |
# | **epa_FuelEcon_score**  | EPA Fuel Economy Score (-1 = Not available)                                 |
# | **est_ann_fuel_cost**   | annual fuel cost for fuelType1 ($)                                          |
# | **fuel_type**           | primary fuel type for single or conventional fuel vehicles                  |
# | **greenhouseGas_Score** | EPA GHG score (-1 = Not available)                                          |
# | **id**                  | vehicle record ID                                                           |
# | **make**                | manufacturer (division)                                                     |
# | **model**               | model name (carline)                                                        |
# | **range**               | estimated range for fuelType1                                               |
# | **trany**               | transmission                                                                |
# | **VClass**              | EPA vehicle size class                                                      |
# | **year**                | model year                                                                  |
# | **5yr_SaveSpend**       | savings/spending over 5 years compared to an average car                    |
# | **base_Model**          | base model name                                                             |
# | **base_fuel_type**      | type of alternative vehicle or fuel                                         |
# | **charger_descript_240**| electric vehicle charger description                                        |
#
# ## Complementary CSV Files
#
# 1. **Fuel Economy Data**: Historical fuel economy data for different vehicle models and years. This can help you analyze trends over time.
#    - Example: Fuel Economy Data Analysis
#
# 2. **Fuel Consumption and CO2 Emissions**: Data on fuel consumption and corresponding CO2 emissions for various vehicles. This can provide insights into the environmental impact of different fuel types.
#    - Example: Fuel Consumption and CO2 Emissions
#
# 3. **Vehicle Specifications**: Detailed specifications of vehicles, including engine size, transmission type, and drive axle type. This can help you correlate vehicle features with fuel efficiency and emissions.
#    - Example: Vehicle Specifications
#
# 4. **Green Vehicle Guide**: Information on vehicles that meet certain environmental standards, such as the EPA's SmartWay certification. This can help you identify environmentally friendly vehicles.
#    - Example: Green Vehicle Guide Documentation
#
# ## CO2 Emissions from Coal-Fired Power Plants
#
# 1. **EPA Power Plant Emissions Data**: This dataset includes quarterly and annual emissions data for CO2, SO2, NOx, and mercury from power plants subject to various EPA regulations.
#    - Example: EPA Power Plant Emissions Data
#
# 2. **IEA CO2 Intensity Data**: This dataset provides information on the average CO2 intensity of power generation from coal power plants over the years.
#    - Example: IEA CO2 Intensity Data
#
# 3. **Global Energy Monitor CO2 Emissions Estimates**: This dataset includes estimates of CO2 emissions from coal plants based on factors such as plant capacity, capacity factor, heat rate, and emission factor.
#    - Example: Global Energy Monitor CO2 Emissions Estimates
#
# ## CO2 Production During Gasoline Production Process
#
# 1. **Analyzing Fuel Carbon Footprints**: This resource provides data on the greenhouse gas emissions from producing and using different fuels for vehicles.
#    - Example: [Analyzing Fuel Carbon Footprints](https://energy.wisc.edu/sites/default/files/2016-12/Fuel%20Carbon%20Footprint%20Data%20Dive%20Teacher%20Pages.pdf)
#
# 2. **CO2 Emissions by Fuel**: This dataset provides information on CO2 emissions from various fuel types, including gasoline.
#    - Example: [CO2 Emissions by Fuel](https://ourworldindata.org/emissions-by-fuel)
#
# 3. **Gasoline and the Environment**: This resource explains the environmental impact of gasoline production and consumption.
#    - Example: [Gasoline and the Environment](https://www.eia.gov/energyexplained/gasoline/gasoline-and-the-environment.php)
